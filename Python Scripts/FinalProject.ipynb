# %% [markdown]
# # Final Project : building a movie recommender tool

# %% [markdown]
# ###### My goal is to build a movie recommender that will give you a list of movies based on various attributes

# %% [markdown]
# - Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import ast
import numpy as np
import json

from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# - Importing the data (from IMDb)

# %% [markdown]
# Explanation of the datasets :
#
#     - names is a file that gave me the data about people
#     - principals is a file that gave me the data about the roles the peopled played (like actor or director)
#     - titles is a file that gave me the movies
#     - ratings is a file that gave me the ratings and votes

# %%
names = pd.read_csv('name.basics.tsv.gz', sep='\t', low_memory=False)

# %%
principals = pd.read_csv('title.principals.tsv.gz', sep='\t', low_memory=False)

# %%
titles = pd.read_csv('title.basics.tsv.gz', sep='\t', low_memory=False)

# %%
ratings = pd.read_csv('title.ratings.tsv.gz', sep='\t', low_memory=False)

# %%
#Making sure we only have actors in our df
names = names[names['primaryProfession'].str.contains('actor|actress', na=False)].copy()

# %%
#Merging names and principals files based on commun denominator 'nconst' to get actors and movies they belong to
file = pd.merge(names, principals, on='nconst', how='inner')

# %%
#Merging with titles based on commun denominator 'tconst'
file2 = pd.merge(file, titles, on='tconst', how='inner')

# %%
#Final merging with ratings based on 'tconst'
df = pd.merge(file2, ratings, on='tconst', how='inner')

# %%
#Saving it as it is
df.to_csv('moviesrec.csv', index=False)

# %% [markdown]
# - Loading the file and exploring it

# %%
df = pd.read_csv('moviesrec.csv')
df
# Out:
# C:\Users\Gladys\AppData\Local\Temp\ipykernel_14128\1530456504.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('moviesrec.csv')
#             nconst            primaryName birthYear deathYear  \
# 0        nm0000001           Fred Astaire      1899      1987
# 1        nm0001677          Ginger Rogers      1911      1995
# 2        nm0002143  Edward Everett Horton      1886      1970
# 3        nm0103567            Alice Brady      1892      1939
# 4        nm0000001           Fred Astaire      1899      1987
# ...            ...                    ...       ...       ...
# 6075698  nm9993124          Gaia Delepine        \N        \N
# 6075699  nm9993125      Alejandro Bordier        \N        \N
# 6075700  nm9993703        James Craigmyle        \N        \N
# 6075701  nm9993703        James Craigmyle        \N        \N
# 6075702  nm9993703        James Craigmyle        \N        \N
#
#                          primaryProfession  \
# 0           soundtrack,actor,miscellaneous
# 1                       actress,soundtrack
# 2                         actor,soundtrack
# 3                       actress,soundtrack
# 4           soundtrack,actor,miscellaneous
# ...                                    ...
# 6075698                     actress,writer
# 6075699  assistant_director,director,actor
# 6075700                              actor
# 6075701                              actor
# 6075702                              actor
#
#                                     knownForTitles      tconst  ordering  \
# 0          tt0031983,tt0072308,tt0053137,tt0050419   tt0025164         1
# 1          tt0035019,tt0032671,tt0044916,tt0031983   tt0025164         2
# 2          tt0057193,tt0036613,tt0027125,tt0030241   tt0025164         4
# 3          tt0025164,tt0029047,tt0028010,tt0024763   tt0025164         3
# 4          tt0031983,tt0072308,tt0053137,tt0050419   tt0026942         2
# ...                                            ...         ...       ...
# 6075698                                  tt8742880   tt8742880         2
# 6075699   tt8866550,tt15310976,tt9121640,tt8742880   tt8742880         1
# 6075700  tt6914160,tt6225166,tt11212278,tt10627062  tt10214478         8
# 6075701  tt6914160,tt6225166,tt11212278,tt10627062  tt11352612         1
# 6075702  tt6914160,tt6225166,tt11212278,tt10627062  tt11720746         1
#
#         category job  ...  titleType               primaryTitle  \
# 0          actor  \N  ...      movie           The Gay Divorcee
# 1        actress  \N  ...      movie           The Gay Divorcee
# 2          actor  \N  ...      movie           The Gay Divorcee
# 3        actress  \N  ...      movie           The Gay Divorcee
# 4          actor  \N  ...      movie                    Roberta
# ...          ...  ..  ...        ...                        ...
# 6075698  actress  \N  ...      short        Entre Deux Stations
# 6075699    actor  \N  ...      short        Entre Deux Stations
# 6075700     self  \N  ...  tvEpisode          Top 10 K9 Moments
# 6075701     self  \N  ...  tvEpisode           Raising the Woof
# 6075702     self  \N  ...  tvEpisode  The Fast and the Furriest
#
#                      originalTitle isAdult  startYear endYear runtimeMinutes  \
# 0                 The Gay Divorcee       0       1934      \N            107
# 1                 The Gay Divorcee       0       1934      \N            107
# 2                 The Gay Divorcee       0       1934      \N            107
# 3                 The Gay Divorcee       0       1934      \N            107
# 4                          Roberta       0       1935      \N            106
# ...                            ...     ...        ...     ...            ...
# 6075698        Entre Deux Stations       0       2017      \N              5
# 6075699        Entre Deux Stations       0       2017      \N              5
# 6075700          Top 10 K9 Moments       0       2019      \N             \N
# 6075701           Raising the Woof       0       2020      \N             41
# 6075702  The Fast and the Furriest       0       2020      \N             41
#
#                          genres averageRating  numVotes
# 0        Comedy,Musical,Romance           7.4      8322
# 1        Comedy,Musical,Romance           7.4      8322
# 2        Comedy,Musical,Romance           7.4      8322
# 3        Comedy,Musical,Romance           7.4      8322
# 4        Comedy,Musical,Romance           7.0      3560
# ...                         ...           ...       ...
# 6075698                   Short           8.9        13
# 6075699                   Short           8.9        13
# 6075700        Crime,Reality-TV           7.5         9
# 6075701              Reality-TV           8.4        16
# 6075702              Reality-TV           7.7         9
#
# [6075703 rows x 21 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of             nconst            primaryName birthYear deathYear  \
# 0        nm0000001           Fred Astaire      1899      1987
# 1        nm0001677          Ginger Rogers      1911      1995
# 2        nm0002143  Edward Everett Horton      1886      1970
# 3        nm0103567            Alice Brady      1892      1939
# 4        nm0000001           Fred Astaire      1899      1987
# ...            ...                    ...       ...       ...
# 6075698  nm9993124          Gaia Delepine        \N        \N
# 6075699  nm9993125      Alejandro Bordier        \N        \N
# 6075700  nm9993703        James Craigmyle        \N        \N
# 6075701  nm9993703        James Craigmyle        \N        \N
# 6075702  nm9993703        James Craigmyle        \N        \N
#
#                          primaryProfession  \
# 0           soundtrack,actor,miscellaneous
# 1                       actress,soundtrack
# 2                         actor,soundtrack
# 3                       actress,soundtrack
# 4           soundtrack,actor,miscellaneous
# ...                                    ...
# 6075698                     actress,writer
# 6075699  assistant_director,director,actor
# 6075700                              actor
# 6075701                              actor
# 6075702                              actor
#
#                                     knownForTitles      tconst  ordering  \
# 0          tt0031983,tt0072308,tt0053137,tt0050419   tt0025164         1
# 1          tt0035019,tt0032671,tt0044916,tt0031983   tt0025164         2
# 2          tt0057193,tt0036613,tt0027125,tt0030241   tt0025164         4
# 3          tt0025164,tt0029047,tt0028010,tt0024763   tt0025164         3
# 4          tt0031983,tt0072308,tt0053137,tt0050419   tt0026942         2
# ...                                            ...         ...       ...
# 6075698                                  tt8742880   tt8742880         2
# 6075699   tt8866550,tt15310976,tt9121640,tt8742880   tt8742880         1
# 6075700  tt6914160,tt6225166,tt11212278,tt10627062  tt10214478         8
# 6075701  tt6914160,tt6225166,tt11212278,tt10627062  tt11352612         1
# 6075702  tt6914160,tt6225166,tt11212278,tt10627062  tt11720746         1
#
#         category job  ...  titleType               primaryTitle  \
# 0          actor  \N  ...      movie           The Gay Divorcee
# 1        actress  \N  ...      movie           The Gay Divorcee
# 2          actor  \N  ...      movie           The Gay Divorcee
# 3        actress  \N  ...      movie           The Gay Divorcee
# 4          actor  \N  ...      movie                    Roberta
# ...          ...  ..  ...        ...                        ...
# 6075698  actress  \N  ...      short        Entre Deux Stations
# 6075699    actor  \N  ...      short        Entre Deux Stations
# 6075700     self  \N  ...  tvEpisode          Top 10 K9 Moments
# 6075701     self  \N  ...  tvEpisode           Raising the Woof
# 6075702     self  \N  ...  tvEpisode  The Fast and the Furriest
#
#                      originalTitle isAdult  startYear endYear runtimeMinutes  \
# 0                 The Gay Divorcee       0       1934      \N            107
# 1                 The Gay Divorcee       0       1934      \N            107
# 2                 The Gay Divorcee       0       1934      \N            107
# 3                 The Gay Divorcee       0       1934      \N            107
# 4                          Roberta       0       1935      \N            106
# ...                            ...     ...        ...     ...            ...
# 6075698        Entre Deux Stations       0       2017      \N              5
# 6075699        Entre Deux Stations       0       2017      \N              5
# 6075700          Top 10 K9 Moments       0       2019      \N             \N
# 6075701           Raising the Woof       0       2020      \N             41
# 6075702  The Fast and the Furriest       0       2020      \N             41
#
#                          genres averageRating  numVotes
# 0        Comedy,Musical,Romance           7.4      8322
# 1        Comedy,Musical,Romance           7.4      8322
# 2        Comedy,Musical,Romance           7.4      8322
# 3        Comedy,Musical,Romance           7.4      8322
# 4        Comedy,Musical,Romance           7.0      3560
# ...                         ...           ...       ...
# 6075698                   Short           8.9        13
# 6075699                   Short           8.9        13
# 6075700        Crime,Reality-TV           7.5         9
# 6075701              Reality-TV           8.4        16
# 6075702              Reality-TV           7.7         9
#
# [6075703 rows x 21 columns]>

# %%
df.columns
# Out:
# Index(['nconst', 'primaryName', 'birthYear', 'deathYear', 'primaryProfession',
#        'knownForTitles', 'tconst', 'ordering', 'category', 'job', 'characters',
#        'titleType', 'primaryTitle', 'originalTitle', 'isAdult', 'startYear',
#        'endYear', 'runtimeMinutes', 'genres', 'averageRating', 'numVotes'],
#       dtype='object')

# %%
#Droppig columns I won't need
df = df.drop(['nconst', 'birthYear', 'deathYear', 'primaryProfession', 'knownForTitles', 'ordering', 'tconst', 'job', 'characters', 'isAdult', 'endYear'], axis=1)

# %%
df
# Out:
#                    primaryName category  titleType               primaryTitle  \
# 0                 Fred Astaire    actor      movie           The Gay Divorcee
# 1                Ginger Rogers  actress      movie           The Gay Divorcee
# 2        Edward Everett Horton    actor      movie           The Gay Divorcee
# 3                  Alice Brady  actress      movie           The Gay Divorcee
# 4                 Fred Astaire    actor      movie                    Roberta
# ...                        ...      ...        ...                        ...
# 6075698          Gaia Delepine  actress      short        Entre Deux Stations
# 6075699      Alejandro Bordier    actor      short        Entre Deux Stations
# 6075700        James Craigmyle     self  tvEpisode          Top 10 K9 Moments
# 6075701        James Craigmyle     self  tvEpisode           Raising the Woof
# 6075702        James Craigmyle     self  tvEpisode  The Fast and the Furriest
#
#                      originalTitle startYear runtimeMinutes  \
# 0                 The Gay Divorcee      1934            107
# 1                 The Gay Divorcee      1934            107
# 2                 The Gay Divorcee      1934            107
# 3                 The Gay Divorcee      1934            107
# 4                          Roberta      1935            106
# ...                            ...       ...            ...
# 6075698        Entre Deux Stations      2017              5
# 6075699        Entre Deux Stations      2017              5
# 6075700          Top 10 K9 Moments      2019             \N
# 6075701           Raising the Woof      2020             41
# 6075702  The Fast and the Furriest      2020             41
#
#                          genres  averageRating  numVotes
# 0        Comedy,Musical,Romance            7.4      8322
# 1        Comedy,Musical,Romance            7.4      8322
# 2        Comedy,Musical,Romance            7.4      8322
# 3        Comedy,Musical,Romance            7.4      8322
# 4        Comedy,Musical,Romance            7.0      3560
# ...                         ...            ...       ...
# 6075698                   Short            8.9        13
# 6075699                   Short            8.9        13
# 6075700        Crime,Reality-TV            7.5         9
# 6075701              Reality-TV            8.4        16
# 6075702              Reality-TV            7.7         9
#
# [6075703 rows x 10 columns]

# %%
#Verifying the nulls
df.isnull().sum()
# Out:
# primaryName       0
# category          0
# titleType         0
# primaryTitle      0
# originalTitle     0
# startYear         0
# runtimeMinutes    0
# genres            3
# averageRating     0
# numVotes          0
# dtype: int64

# %%
#I dont want to drop the 3 movies concerned so I'll replace with Unknown
df['genres'] = df['genres'].fillna('Unknown')

# %%
df.isnull().sum()
# Out:
# primaryName       0
# category          0
# titleType         0
# primaryTitle      0
# originalTitle     0
# startYear         0
# runtimeMinutes    0
# genres            0
# averageRating     0
# numVotes          0
# dtype: int64

# %%
#Renaming some columns to make it more beautiful
df = df.rename(columns={
    'primaryName': 'actor/actress',
    'titleType': 'type',
    'primaryTitle': 'title',
    'startYear': 'year',
    'runtimeMinutes': 'duration',
    'averageRating': 'rating',
    'numVotes': 'votes'
})

# %%
df
# Out:
#                  actor/actress category       type                      title  \
# 0                 Fred Astaire    actor      movie           The Gay Divorcee
# 1                Ginger Rogers  actress      movie           The Gay Divorcee
# 2        Edward Everett Horton    actor      movie           The Gay Divorcee
# 3                  Alice Brady  actress      movie           The Gay Divorcee
# 4                 Fred Astaire    actor      movie                    Roberta
# ...                        ...      ...        ...                        ...
# 6075698          Gaia Delepine  actress      short        Entre Deux Stations
# 6075699      Alejandro Bordier    actor      short        Entre Deux Stations
# 6075700        James Craigmyle     self  tvEpisode          Top 10 K9 Moments
# 6075701        James Craigmyle     self  tvEpisode           Raising the Woof
# 6075702        James Craigmyle     self  tvEpisode  The Fast and the Furriest
#
#                      originalTitle  year duration                  genres  \
# 0                 The Gay Divorcee  1934      107  Comedy,Musical,Romance
# 1                 The Gay Divorcee  1934      107  Comedy,Musical,Romance
# 2                 The Gay Divorcee  1934      107  Comedy,Musical,Romance
# 3                 The Gay Divorcee  1934      107  Comedy,Musical,Romance
# 4                          Roberta  1935      106  Comedy,Musical,Romance
# ...                            ...   ...      ...                     ...
# 6075698        Entre Deux Stations  2017        5                   Short
# 6075699        Entre Deux Stations  2017        5                   Short
# 6075700          Top 10 K9 Moments  2019       \N        Crime,Reality-TV
# 6075701           Raising the Woof  2020       41              Reality-TV
# 6075702  The Fast and the Furriest  2020       41              Reality-TV
#
#          rating  votes
# 0           7.4   8322
# 1           7.4   8322
# 2           7.4   8322
# 3           7.4   8322
# 4           7.0   3560
# ...         ...    ...
# 6075698     8.9     13
# 6075699     8.9     13
# 6075700     7.5      9
# 6075701     8.4     16
# 6075702     7.7      9
#
# [6075703 rows x 10 columns]

# %%
#dropping originalTitle
df = df.drop('originalTitle', axis=1)

# %%
df
# Out:
#                  actor/actress category       type                      title  \
# 0                 Fred Astaire    actor      movie           The Gay Divorcee
# 1                Ginger Rogers  actress      movie           The Gay Divorcee
# 2        Edward Everett Horton    actor      movie           The Gay Divorcee
# 3                  Alice Brady  actress      movie           The Gay Divorcee
# 4                 Fred Astaire    actor      movie                    Roberta
# ...                        ...      ...        ...                        ...
# 6075698          Gaia Delepine  actress      short        Entre Deux Stations
# 6075699      Alejandro Bordier    actor      short        Entre Deux Stations
# 6075700        James Craigmyle     self  tvEpisode          Top 10 K9 Moments
# 6075701        James Craigmyle     self  tvEpisode           Raising the Woof
# 6075702        James Craigmyle     self  tvEpisode  The Fast and the Furriest
#
#          year duration                  genres  rating  votes
# 0        1934      107  Comedy,Musical,Romance     7.4   8322
# 1        1934      107  Comedy,Musical,Romance     7.4   8322
# 2        1934      107  Comedy,Musical,Romance     7.4   8322
# 3        1934      107  Comedy,Musical,Romance     7.4   8322
# 4        1935      106  Comedy,Musical,Romance     7.0   3560
# ...       ...      ...                     ...     ...    ...
# 6075698  2017        5                   Short     8.9     13
# 6075699  2017        5                   Short     8.9     13
# 6075700  2019       \N        Crime,Reality-TV     7.5      9
# 6075701  2020       41              Reality-TV     8.4     16
# 6075702  2020       41              Reality-TV     7.7      9
#
# [6075703 rows x 9 columns]

# %%
df.to_csv('cleaned_movies.csv', index=False)

# %%
#I used 3 youtube videos to undrstand how to do my function. For reference, here they are : https://www.youtube.com/watch?v=9Os0o3wzS_I , https://www.youtube.com/watch?v=2AFGPdNn4FM

# %% [markdown]
# - Movie recommender solely based on actors

# %%
def gladys_recommender(actor_name, num_movies=5):
    actor_movies = df[df['actor/actress'] == actor_name]
    
    sorted_movies = actor_movies.sort_values(by='rating', ascending=False)

    return sorted_movies['title'].head(num_movies)

# %%
gladys_recommender('Jean Dujardin', 5)
# Out:
# 3371044           À la banque
# 3371086     Dans le vercors 3
# 3371084    Dans la cuisine 12
# 3371059        Au téléphone 8
# 3371046        À la librairie
# Name: title, dtype: object

# %%
gladys_recommender('Thierry Lhermitte', 5)
# Out:
# 2874017         Philippe Noiret: Gentleman saltimbanque
# 2590649                        Une camisole pour le Doc
# 916331                      Le père Noël est une ordure
# 4279524    Les pouvoirs extraordinaires du corps humain
# 2531814                               Trop, c'est trop!
# Name: title, dtype: object

# %%
gladys_recommender('Dev Patel', 5)
# Out:
# 119275                Lion: The Journey Home
# 2770689                           Roborovski
# 3454941                                Chris
# 623722                          The Newsroom
# 757388     When Cupid Is a Prying Journalist
# Name: title, dtype: object

# %%
gladys_recommender('Antonio Banderas', 5)
# Out:
# 57067                 Operation Bobbi Bear
# 56619       Vanity Fair: Hollywood Calling
# 56609             Escena en blanco y negro
# 36757          Besser als mein Haus je war
# 56273    Premio Donostia a Anthony Hopkins
# Name: title, dtype: object

# %%
gladys_recommender('Freida Pinto', 5)
# Out:
# 3161131         A New American Religion
# 291123                    Episode #5.95
# 4049492    Nargis Fakhri & Freida Pinto
# 555612              Slumdog Millionaire
# 3161116                        The Veil
# Name: title, dtype: object

# %%
gladys_recommender('Julia Roberts', 5)
# Out:
# 143590                      Cheetahs with Holly Hunter
# 143682    Wild Horsemen of Mongolia with Julia Roberts
# 143572                        Episode dated 4 May 2006
# 97117                   Premio Donostia a Richard Gere
# 39375                                        Brad Pitt
# Name: title, dtype: object

# %%
gladys_recommender('Tom Cruise', 5)
# Out:
# 76673                                           Diane Lane
# 41089                                      Success Formula
# 77424    Mission: Impossible: Fallout - Behind the Scen...
# 77413                             War of the Worlds (2005)
# 77679    Scientology and Celebrity: The Betrayal of Pau...
# Name: title, dtype: object

# %% [markdown]
# - Movie recommender based on actors and only including movies

# %%
def gladys_movies(actor_name, num_movies=5):
    actor_movies = df[(df['actor/actress'] == actor_name) & (df['type'] == 'movie')]

    sorted_movies = actor_movies.sort_values(by='rating', ascending=False)

    return sorted_movies['title'].head(num_movies)

# %%
gladys_movies('Julia Roberts', 5)
# Out:
# 143692             Wonder
# 39260      Ocean's Eleven
# 143516    Erin Brockovich
# 143465    Steel Magnolias
# 143512       Notting Hill
# Name: title, dtype: object

# %%
gladys_movies('Jean Dujardin', 5)
# Out:
# 245160                The Artist
# 3371078    Sur les chemins noirs
# 1041327                99 francs
# 1842715        Little White Lies
# 1041393           The Connection
# Name: title, dtype: object

# %%
gladys_movies('Michael Jackson', 5)
# Out:
# 747087             Michael Jackson Commemorated
# 747005                         Loving Neverland
# 332986                 Michael Jackson What If?
# 391399    Michael Jackson: Smooth Criminal (II)
# 747069                             Ramin Fallah
# Name: title, dtype: object

# %%
gladys_movies('Sandra Bullock', 5)
# Out:
# 64202                      Waking in Mississippi
# 64523    No Subtitles Necessary: Laszlo & Vilmos
# 64573                                    Gravity
# 64252                                      Crash
# 64485                             The Blind Side
# Name: title, dtype: object

# %%
gladys_movies('Anne Hathaway', 5)
# Out:
# 132010             Interstellar
# 138374    The Dark Knight Rises
# 143458              Dark Waters
# 76265            Les Misérables
# 81296                The Intern
# Name: title, dtype: object

# %% [markdown]
# - Movie recommender based on actors, using the attribute genre

# %%
def gladys_top_movies(actor_name, num_movies=5):
    actor_movies = df[(df['actor/actress'] == actor_name) & (df['type'] == 'movie')]

    sorted_movies = actor_movies.sort_values(by='rating', ascending=False)
    
    top_movies = sorted_movies.head(num_movies)

    return top_movies

# %%
gladys_top_movies('Ryan Gosling', 5)
# Out:
#         actor/actress category   type                             title  year  \
# 3728452  Ryan Gosling    actor  movie                        La La Land  2016
# 92628    Ryan Gosling    actor  movie                 Blade Runner 2049  2017
# 3531185  Ryan Gosling     self  movie  Screenplay Series with Syd Field  2007
# 592512   Ryan Gosling    actor  movie                      The Notebook  2004
# 39778    Ryan Gosling    actor  movie                     The Big Short  2015
#
#         duration                  genres  rating   votes
# 3728452      128      Comedy,Drama,Music     8.0  621727
# 92628        164    Action,Drama,Mystery     8.0  611680
# 3531185       90               Biography     8.0      11
# 592512       123           Drama,Romance     7.8  591588
# 39778        130  Biography,Comedy,Drama     7.8  451877

# %%
gladys_top_movies('Viola Davis', 5)
# Out:
#         actor/actress category   type             title  year duration  \
# 3196391   Viola Davis  actress  movie          The Help  2011      146
# 3196373   Viola Davis  actress  movie         Prisoners  2013      153
# 309382    Viola Davis  actress  movie             Doubt  2008      104
# 163549    Viola Davis  actress  movie            Fences  2016      139
# 64541     Viola Davis  actress  movie  The Unforgivable  2021      112
#
#                       genres  rating   votes
# 3196391                Drama     8.1  475350
# 3196373  Crime,Drama,Mystery     8.1  755995
# 309382         Drama,Mystery     7.5  133343
# 163549                 Drama     7.2  112875
# 64541            Crime,Drama     7.1  114471

# %%
gladys_top_movies('Channing Tatum', 5)
# Out:
#           actor/actress category   type             title  year duration  \
# 390455   Channing Tatum    actor  movie  The Book of Life  2014       95
# 616713   Channing Tatum    actor  movie    21 Jump Street  2012      109
# 124613   Channing Tatum    actor  movie      Side Effects  2013      106
# 616774   Channing Tatum    actor  movie    22 Jump Street  2014      112
# 1820606  Channing Tatum    actor  movie       Logan Lucky  2017      118
#
#                              genres  rating   votes
# 390455   Adventure,Animation,Comedy     7.2   74636
# 616713          Action,Comedy,Crime     7.2  578521
# 124613          Crime,Drama,Mystery     7.1  194065
# 616774          Action,Comedy,Crime     7.0  391771
# 1820606         Action,Comedy,Crime     7.0  156142

# %%
gladys_top_movies('Nora Fatehi', 5)
# Out:
#         actor/actress category   type             title  year duration  \
# 5338045   Nora Fatehi  actress  movie       Batla House  2019      146
# 4693008   Nora Fatehi  actress  movie  My Birthday Song  2018       95
# 3278836   Nora Fatehi  actress  movie  Street Dancer 3D  2020      146
#
#                      genres  rating  votes
# 5338045  Action,Crime,Drama     7.2  12261
# 4693008            Thriller     5.6    308
# 3278836         Drama,Music     3.6   7765

# %%
gladys_top_movies('Chiwetel Ejiofor', 5)
# Out:
#             actor/actress category   type               title  year duration  \
# 39817    Chiwetel Ejiofor    actor  movie    12 Years a Slave  2013      134
# 136229   Chiwetel Ejiofor    actor  movie     Children of Men  2006      109
# 3426597  Chiwetel Ejiofor    actor  movie            Serenity  2005      119
# 3426751  Chiwetel Ejiofor     self  movie  The Elephant Queen  2018       96
# 76075    Chiwetel Ejiofor    actor  movie   American Gangster  2007      157
#
#                           genres  rating   votes
# 39817    Biography,Drama,History     8.1  719434
# 136229       Action,Drama,Sci-Fi     7.9  513833
# 3426597  Action,Adventure,Sci-Fi     7.8  301097
# 3426751       Documentary,Family     7.8    2181
# 76075      Biography,Crime,Drama     7.8  438903

# %%
gladys_top_movies('Danai Gurira', 5)
# Out:
#         actor/actress category   type                           title  year  \
# 1341376  Danai Gurira  actress  movie                     The Visitor  2007
# 4065721  Danai Gurira  actress  movie                   Black Panther  2018
# 4260823  Danai Gurira  actress  movie  Black Panther: Wakanda Forever  2022
# 3205291  Danai Gurira  actress  movie                Mother of George  2013
# 3717983  Danai Gurira  actress  movie                  All Eyez on Me  2017
#
#         duration                   genres  rating   votes
# 1341376      104                    Drama     7.6   43908
# 4065721      134  Action,Adventure,Sci-Fi     7.3  807651
# 4260823      161   Action,Adventure,Drama     6.7  277852
# 3205291      107                    Drama     6.5    1249
# 3717983      139    Biography,Drama,Music     5.9   24149

# %%
gladys_top_movies('Michael Jackson', 5)
# Out:
#           actor/actress         category   type  \
# 747087  Michael Jackson  archive_footage  movie
# 747005  Michael Jackson  archive_footage  movie
# 332986  Michael Jackson  archive_footage  movie
# 391399  Michael Jackson            actor  movie
# 747069  Michael Jackson  archive_footage  movie
#
#                                         title  year duration  \
# 747087           Michael Jackson Commemorated  2010      119
# 747005                       Loving Neverland  2020      315
# 332986               Michael Jackson What If?  2017      107
# 391399  Michael Jackson: Smooth Criminal (II)  1988       48
# 747069                           Ramin Fallah  2021      112
#
#                        genres  rating  votes
# 747087  Biography,Documentary     9.1     23
# 747005            Documentary     8.8    262
# 332986  Biography,Documentary     8.7     16
# 391399   Action,Crime,Fantasy     8.5    613
# 747069  Biography,Documentary     8.4      7
